# %% [markdown]
# `data/sequences` contains csv files for interesting numberical sequences.
#
# Plot all these sequences on the same plot with a legend identifying which is which.  You should aim for your plot to look something like this
#
# ![](../imgs/solutions/sequences.png)

# %%
# put your solution here
import pandas
sequences = pandas.read_csv("../data/sequences.csv").drop("id", axis=1)
sequences.plot()
# Out:
# <Axes: >
